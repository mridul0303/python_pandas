# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # Random selection from pandas

# %%
df.sample(frac=0.5,random_state=42)
# Out:
#        age         workclass  fnlwgt   education  educational-num  \
# 7762    56           Private   33115     HS-grad                9
# 23881   25           Private  112847     HS-grad                9
# 30507   43           Private  170525   Bachelors               13
# 28911   32           Private  186788     HS-grad                9
# 19484   39           Private  277886   Bachelors               13
# ...    ...               ...     ...         ...              ...
# 18837   55           Private  320835   Bachelors               13
# 37171   35  Self-emp-not-inc  170174     HS-grad                9
# 18234   21           Private  165475     HS-grad                9
# 27814   24           Private  173679   Assoc-voc               11
# 41169   54           Private  103580  Assoc-acdm               12
#
#            marital-status         occupation   relationship   race  gender  \
# 7762             Divorced      Other-service      Unmarried  White  Female
# ...

# %%
df.sample(n=int(len(df.index)/2))
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 4733    28           Private  230503  Some-college               10
# 2338    31  Self-emp-not-inc  271173  Some-college               10
# 24125   35           Private  107302       Masters               14
# 42961   32           Private  137875  Some-college               10
# 21493   34  Self-emp-not-inc  174463     Assoc-voc               11
# ...    ...               ...     ...           ...              ...
# 8606    35           Private  397877       HS-grad                9
# 21804   39           Private  174368       HS-grad                9
# 4833    63           Private   65740  Some-college               10
# 11460   22           Private  443336  Some-college               10
# 44357   41           Private  211253       Masters               14
#
#            marital-status         occupation   relationship  \
# 4733        Never-married       Tech-support      Unmarried
# ...

# %%
df[df.isnull()].count()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Replace "?" with NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.replace("?",np.nan)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df[df.isin(["?"])].count()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df=df.replace("?",np.nan)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.isin(["?"]).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.isin([np.nan]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %% [markdown]
# # Skipping missing values

# %%
df.isin([np.nan]).sum()*100/len(df)
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df=df.dropna(how="any")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 47

# %%
df[df.duplicated()].count()# equal to count as no missing values
# Out:
# age                47
# workclass          47
# fnlwgt             47
# education          47
# educational-num    47
# marital-status     47
# occupation         47
# relationship       47
# race               47
# gender             47
# capital-gain       47
# capital-loss       47
# hours-per-week     47
# native-country     47
# income             47
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
df["educational-num"]
# Out:
# 0         7
# 1         9
# 2        12
# 3        10
# 5         6
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: educational-num, Length: 45222, dtype: int64

# %%
df=df.drop(["educational-num","capital-gain","capital-loss"],axis=1)
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# # distribution

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df[df.age.between(17,48)].sum()["age"]
# Out:
# 1150833

# %%
df.age.between(17,48).sum()
# Out:
# 34902

# %%
df.workclass.hist()
plt.figure(figsize=(10,10))   #increases fig size

# %%
plt.figure(figsize=(10,10))   #used before to increase then plot
df.workclass.hist()
# Out:
# <AxesSubplot:>

# %%
df.education.unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df.education.isin(['Bachelors','Masters']).sum()
# Out:
# 10084

# %% [markdown]
# # bivariate analysis

# %%
df.income.value_counts()
# Out:
# <=50K    34014
# >50K     11208
# Name: income, dtype: int64

# %%
sns.boxplot(x="income",y="age",data=df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %% [markdown]
# # encoding income into 1 and 0

# %%
sns.countplot(x="income",data=df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
df.income.hist()
# Out:
# <AxesSubplot:>

# %%
#df.replace(["<=50K",">50K"],[0,1])

# %%
#df["inc_dist"]=df["income"].map({"<=50K":0,">50K":1})
#df.drop(["income"],axis=1)

# %%
def fun(income):
    if income=="<=50K":
        return 0
    else:
        return 1

# %%
df["encoded"]=df["income"].apply(fun)
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
df["encoded"].value_counts()
# Out:
# 0    34014
# 1    11208
# Name: encoded, dtype: int64

# %%
df[df["income"]=='<=50K']["workclass"].value_counts()
# Out:
# Private             26056
# Self-emp-not-inc     2737
# Local-gov            2185
# State-gov            1426
# Federal-gov           857
# Self-emp-inc          734
# Without-pay            19
# Name: workclass, dtype: int64

# %% [markdown]
# # maximum no. in workclass having high salary

# %%
df[df["income"]=='>50K']["workclass"].value_counts().head()
# Out:
# Private             7251
# Self-emp-not-inc    1059
# Local-gov            915
# Self-emp-inc         912
# Federal-gov          549
# Name: workclass, dtype: int64

# %%
df[df["encoded"]==1]["workclass"].value_counts().head()
# Out:
# Private             7251
# Self-emp-not-inc    1059
# Local-gov            915
# Self-emp-inc         912
# Federal-gov          549
# Name: workclass, dtype: int64

# %% [markdown]
# # workclass paying the highest salary

# %%
df.groupby(["workclass"]).mean()
# Out:
#                         age         fnlwgt  hours-per-week   encoded
# workclass
# Federal-gov       42.593172  183752.510669       41.433144  0.390469
# Local-gov         41.651290  190138.732581       40.865484  0.295161
# Private           36.889633  192616.517429       40.258925  0.217702
# Self-emp-inc      45.804374  178892.302552       48.578372  0.554070
# Self-emp-not-inc  45.367229  175085.025026       44.429136  0.278978
# State-gov         39.530319  182073.107400       39.121788  0.267215
# Without-pay       47.285714  167902.666667       33.952381  0.095238

# %%
df.groupby("workclass")["encoded"].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554070
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.278978
# State-gov           0.267215
# Private             0.217702
# Without-pay         0.095238
# Name: encoded, dtype: float64

# %%
df.groupby(["gender","workclass"])["encoded"].mean().sort_values(ascending=False)
# Out:
# gender  workclass
# Male    Self-emp-inc        0.588804
#         Federal-gov         0.485952
#         Local-gov           0.372845
#         State-gov           0.354324
# Female  Self-emp-inc        0.301508
# Male    Self-emp-not-inc    0.295061
#         Private             0.281868
# Female  Self-emp-not-inc    0.196110
#         Federal-gov         0.184270
#         Local-gov           0.179260
#         Without-pay         0.142857
#         State-gov           0.129801
#         Private             0.094855
# Male    Without-pay         0.071429
# Name: encoded, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  object
#  2   fnlwgt          45222 non-null  int64
#  3   education       45222 non-null  object
#  4   marital-status  45222 non-null  object
#  5   occupation      45222 non-null  object
#  6   relationship    45222 non-null  object
#  7   race            45222 non-null  object
#  8   gender          45222 non-null  object
#  9   hours-per-week  45222 non-null  int64
#  10  native-country  45222 non-null  object
#  11  income          45222 non-null  object
#  12  encoded         45222 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 5.8+ MB

# %%
df.workclass=df.workclass.astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  category
#  2   fnlwgt          45222 non-null  int64
#  3   education       45222 non-null  object
#  4   marital-status  45222 non-null  object
#  5   occupation      45222 non-null  object
#  6   relationship    45222 non-null  object
#  7   race            45222 non-null  object
#  8   gender          45222 non-null  object
#  9   hours-per-week  45222 non-null  int64
#  10  native-country  45222 non-null  object
#  11  income          45222 non-null  object
#  12  encoded         45222 non-null  int64
# dtypes: category(1), int64(4), object(8)
# memory usage: 5.5+ MB
