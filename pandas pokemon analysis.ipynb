# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('Pokemon.csv')
#df=pd.read_csv('Pokemon.txt',delimiter='\t') =gives files in one column while separeted by dilimeter
#df_xlsx=pd.read_excel('Pokemon.xlsx')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head(3)#if no argument then 5 by default
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
#read and calling  with indexes headers
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df[["Name","Type 1"]][-5:-1]
# Out:
#                     Name   Type 1
# 795              Diancie     Rock
# 796  DiancieMega Diancie     Rock
# 797  HoopaHoopa Confined  Psychic
# 798   HoopaHoopa Unbound  Psychic

# %%
#rows and specific location calling
df.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
#for index,rows in df.iterrows():
    #print(index,rows['Name'])

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
df.loc[df['Type 1']=="Fire"]#location for type of data
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values(['Type 1','HP'], ascending=[1,0])#name=alphabetically ordered
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# ..   ...                      ...    ...       ...    ...  ..     ...
# 106   98                   Krabby  Water       NaN    325  30     105
# 125  116                   Horsea  Water       NaN    295  30      40
# 129  120                   Staryu  Water       NaN    340  30      45
# 139  129                 Magikarp  Water       NaN    200  20      10
# 381  349                   Feebas  Water       NaN    200  20      15
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520       86      116       56     95           4      False
# ...

# %% [markdown]
# # Making changes to data

# %%
df['Total 2']=df["HP"]+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total 2
# 0       65       65     45           1      False      318
# 1       80       80     60           1      False      405
# 2      100      100     80           1      False      525
# 3      122      120     80           1      False      625
# 4       60       50     65           1      False      309

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total 2
# 0         65       65     45           1      False      318
# ...

# %%
df['Total 3']=df.iloc[0:5,5:11].sum(axis=1)
df#axis=1=horizontal summing
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
coloumns=list(df.columns)
df=df[coloumns[5:11]]
df
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %% [markdown]
# # s\Saving in different extension

# %%
df.to_csv('modified.csv',index=False)

# %%
df.to_excel('modified2.xlsx')

# %%
df.to_csv('modified3.txt',sep="\t")

# %% [markdown]
# # Filtering Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('Pokemon.csv')
df.loc[(df['HP']==80) & (df['Defense']==60)]
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True

# %%
df=df.reset_index()#indexes values if elimination and arrangement got unordered
df
# Out:
#      index    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0        0    1              Bulbasaur    Grass  Poison    318  45      49
# 1        1    2                Ivysaur    Grass  Poison    405  60      62
# 2        2    3               Venusaur    Grass  Poison    525  80      82
# 3        3    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        4    4             Charmander     Fire     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    795  719                Diancie     Rock   Fairy    600  50     100
# 796    796  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    799  721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.reset_index(drop=True,inplace=True)#drop=true if you wanna remove index column

df#inplace=True if you dont wanna assign it a new variable
# Out:
#      index    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0        0    1              Bulbasaur    Grass  Poison    318  45      49
# 1        1    2                Ivysaur    Grass  Poison    405  60      62
# 2        2    3               Venusaur    Grass  Poison    525  80      82
# 3        3    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        4    4             Charmander     Fire     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    795  719                Diancie     Rock   Fairy    600  50     100
# 796    796  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    799  721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df=pd.read_csv('Pokemon.csv')
df.loc[df['Name'].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
df.loc[~df['Name'].str.contains("Mega")]#reverse of upper
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'].str.contains("Fire|Grass")]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re#regular
df.loc[df['Type 1'].str.contains("fire|grass", flags=re.I , regex=True)]
#flags=re.I  ,gives values of characters regardless capitlaization
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Conditional changes

# %%
df.loc[df['Type 1']=='Fire',['Type 1','Generation']] =['Fiesty',66]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Fiesty     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Fiesty   Water    600  80     110      120
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df.loc[len(df.index)]=df.iloc[0:5,5:11].sum(axis=0)#adding  a row
df
# Out:
#          #                   Name   Type 1  Type 2  Total     HP  Attack  \
# 0      1.0              Bulbasaur    Grass  Poison  318.0   45.0    49.0
# 1      2.0                Ivysaur    Grass  Poison  405.0   60.0    62.0
# 2      3.0               Venusaur    Grass  Poison  525.0   80.0    82.0
# 3      3.0  VenusaurMega Venusaur    Grass  Poison  625.0   80.0   100.0
# 4      4.0             Charmander   Fiesty     NaN  309.0   39.0    52.0
# ..     ...                    ...      ...     ...    ...    ...     ...
# 796  719.0    DiancieMega Diancie     Rock   Fairy  700.0   50.0   160.0
# 797  720.0    HoopaHoopa Confined  Psychic   Ghost  600.0   80.0   110.0
# 798  720.0     HoopaHoopa Unbound  Psychic    Dark  680.0   80.0   160.0
# 799  721.0              Volcanion   Fiesty   Water  600.0   80.0   110.0
# 800    NaN                    NaN      NaN     NaN    NaN  304.0   345.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
total=df.iloc[0:4,5:11].sum(axis=0)
df=df.append(total , ignore_index = True)
df
# Out:
#          #                   Name   Type 1  Type 2  Total     HP  Attack  \
# 0      1.0              Bulbasaur    Grass  Poison  318.0   45.0    49.0
# 1      2.0                Ivysaur    Grass  Poison  405.0   60.0    62.0
# 2      3.0               Venusaur    Grass  Poison  525.0   80.0    82.0
# 3      3.0  VenusaurMega Venusaur    Grass  Poison  625.0   80.0   100.0
# 4      4.0             Charmander   Fiesty     NaN  309.0   39.0    52.0
# ..     ...                    ...      ...     ...    ...    ...     ...
# 797  720.0    HoopaHoopa Confined  Psychic   Ghost  600.0   80.0   110.0
# 798  720.0     HoopaHoopa Unbound  Psychic    Dark  680.0   80.0   160.0
# 799  721.0              Volcanion   Fiesty   Water  600.0   80.0   110.0
# 800    NaN                    NaN      NaN     NaN    NaN  304.0   345.0
# 801    NaN                    NaN      NaN     NaN    NaN  265.0   293.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.groupby(['Type 1','Type 2']).mean()
# Out:
#                           #       Total         HP      Attack     Defense  \
# Type 1 Type 2
# Bug    Electric  595.500000  395.500000  60.000000   62.000000   55.000000
#        Fighting  214.000000  550.000000  80.000000  155.000000   95.000000
#        Fire      636.500000  455.000000  70.000000   72.500000   60.000000
#        Flying    286.285714  419.500000  63.000000   70.142857   61.571429
#        Ghost     292.000000  236.000000   1.000000   90.000000   45.000000
# ...                     ...         ...        ...         ...         ...
# Water  Ice       103.000000  511.666667  90.000000   83.333333  113.333333
#        Poison    118.666667  426.666667  61.666667   68.333333   58.333333
#        Psychic   111.800000  481.000000  87.000000   73.000000  104.000000
#        Rock      430.000000  428.750000  70.750000   82.750000  112.750000
#        Steel     395.000000  530.000000  84.000000   86.000000   88.000000
#
# ...

# %%
df.groupby(['Type 1','Type 2']).sum()
# Out:
#                       #   Total     HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Bug    Electric  1191.0   791.0  120.0   124.0    110.0    154.0    110.0
#        Fighting   428.0  1100.0  160.0   310.0    190.0     80.0    200.0
#        Fire      1273.0   910.0  140.0   145.0    120.0    185.0    160.0
#        Flying    4008.0  5873.0  882.0   982.0    862.0   1020.0    967.0
#        Ghost      292.0   236.0    1.0    90.0     45.0     30.0     30.0
# ...                 ...     ...    ...     ...      ...      ...      ...
# Water  Ice        309.0  1535.0  270.0   250.0    340.0    240.0    235.0
#        Poison     356.0  1280.0  185.0   205.0    175.0    185.0    275.0
#        Psychic    559.0  2405.0  435.0   365.0    520.0    470.0    395.0
#        Rock      1720.0  1715.0  283.0   331.0    451.0    246.0    260.0
#        Steel      395.0   530.0   84.0    86.0     88.0    111.0    101.0
#
#                   Speed  Generation  Legendary
# Type 1 Type 2
# ...

# %%
'''new_df = pd.Dataframe(columns=df.columns)

for df in pd.read_csv('Pokemon.csv',chunksize=5):
    results=df.groupby(['Type 1']).count()
    
    new_df=pd.concat([new_df,results])'''
# Out:
# "new_df = pd.Dataframe(columns=df.columns)\n\nfor df in pd.read_csv('Pokemon.csv',chunksize=5):\n    results=df.groupby(['Type 1']).count()\n    \n    new_df=pd.concat([new_df,results])"

# %%
df.groupby(['Type 1','Type 2']).count()
# Out:
#                   #  Name  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Bug    Electric   2     2      2   2       2        2        2        2
#        Fighting   2     2      2   2       2        2        2        2
#        Fire       2     2      2   2       2        2        2        2
#        Flying    14    14     14  14      14       14       14       14
#        Ghost      1     1      1   1       1        1        1        1
# ...              ..   ...    ...  ..     ...      ...      ...      ...
# Water  Ice        3     3      3   3       3        3        3        3
#        Poison     3     3      3   3       3        3        3        3
#        Psychic    5     5      5   5       5        5        5        5
#        Rock       4     4      4   4       4        4        4        4
#        Steel      1     1      1   1       1        1        1        1
#
#                  Speed  Generation  Legendary
# Type 1 Type 2
# ...
